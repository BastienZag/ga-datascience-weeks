# %%
# !pip install html5lib
# Out:
# ...
#     100% |████████████████████████████████| 122kB 2.4MB/s ta 0:00:01
# ...
# done
#   Stored in directory: /Users/Bastien/Library/Caches/pip/wheels/0a/73/c2/1dcc99951b6aeac495e7695505d1837616ca194938f07d1d7b
# Successfully built webencodings
# ...

# %%
# !pip install BeautifulSoup4
import pandas

# %%
list_of_tables = pandas.read_html('http://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population', header = 0, index_col = 1)

# %%
len(list_of_tables)
# Out:
# 3

# %%
population = list_of_tables[1]

# %%
population
# Out:
#                                                   Rank  Population  \
# Country (or dependent territory)
# China[Note 2]                                        1  1381450000
# India                                                2  1311740000
# United States[Note 3]                                3   324503000
# Indonesia                                            4   260581000
# Brazil                                               5   207074000
# Pakistan                                             6   196310000
# Nigeria                                              7   186988000
# Bangladesh                                           8   161913000
# Russia[Note 4]                                       9   146838993
# Japan                                               10   126860000
# Mexico                                              11   122273000
# Philippines                                         12   103743000
# ...
